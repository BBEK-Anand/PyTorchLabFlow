# %%
from PTLF.lab import *

# %%
null = None
settings = {
    "project_name": "project_name",
    "data_path": "path/to/your/project/dir",
    "component_dir": "path/to/your/component/dir",
    "metrics":["accuracy", "auroc", "f1score","auprc"],
    "strategy":{"monitor":"val_loss","mode":"min"}
}
from PTLF.lab import create_project
create_project(settings=settings)
# Out:
# 'D:\\stdML\\Py310\\Adult\\ProjectInternal\\data\\setting.json'
